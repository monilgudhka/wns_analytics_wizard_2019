# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Reading all data

# %%
# Read Items
item_df = pd.read_csv('data/train/item_data.csv', index_col='item_id')
item_df.head()
# Out:
#          item_price  category_1  category_2  category_3  product_type
# item_id
# 26880          4602          11          35          20          3040
# 54939          3513          12          57          85          6822
# 40383           825          17           8         279          1619
# 8777           2355          13          58         189          5264
# 113705         1267          17          39         151         10239

# %%
# Reading view logs
user_log_df = pd.read_csv('data/train/view_log.csv', parse_dates=['server_time'])
user_log_df.head()
# Out:
#           server_time device_type  session_id  user_id  item_id
# 0 2018-10-15 08:58:00     android      112333     4557    32970
# 1 2018-10-15 08:58:00     android      503590    74788     7640
# 2 2018-10-15 08:58:00     android      573960    23628   128855
# 3 2018-10-15 08:58:00     android      121691     2430    12774
# 4 2018-10-15 08:58:00     android      218564    19227    28296

# %%
training_data = pd.read_csv('data/train/train.csv', index_col='impression_id', parse_dates=['impression_time'])
training_data.head()
# Out:
#                                      impression_time  user_id  app_code  \
# impression_id
# c4ca4238a0b923820dcc509a6f75849b 2018-11-15 00:00:00    87862       422
# 45c48cce2e2d7fbdea1afc51c7c6ad26 2018-11-15 00:01:00    63410       467
# 70efdf2ec9b086079795c442636b55fb 2018-11-15 00:02:00    71748       259
# 8e296a067a37563370ded05f5a3bf3ec 2018-11-15 00:02:00    69209       244
# 182be0c5cdcd5072bb1864cdee4d3d6e 2018-11-15 00:02:00    62873       473
#
#                                     os_version  is_4G  is_click
# impression_id
# c4ca4238a0b923820dcc509a6f75849b           old      0         0
# 45c48cce2e2d7fbdea1afc51c7c6ad26        latest      1         1
# 70efdf2ec9b086079795c442636b55fb  intermediate      1         0
# 8e296a067a37563370ded05f5a3bf3ec        latest      1         0
# 182be0c5cdcd5072bb1864cdee4d3d6e        latest      0         0

# %%
testing_data = pd.read_csv('data/test/test.csv', index_col='impression_id', parse_dates=['impression_time'])
testing_data.head()
# Out:
#                                      impression_time  user_id  app_code  \
# impression_id
# a9e7126a585a69a32bc7414e9d0c0ada 2018-12-13 07:44:00    44754       127
# caac14a5bf2ba283db7708bb34855760 2018-12-13 07:45:00    29656        44
# 13f10ba306a19ce7bec2f3cae507b698 2018-12-13 07:46:00    25234       296
# 39c4b4dc0e9701b55a0a4f072008fb3f 2018-12-13 07:47:00    22988       207
# bf5a572cca75f5fc67f4b14e58b11d70 2018-12-13 07:48:00    35431       242
#
#                                  os_version  is_4G
# impression_id
# a9e7126a585a69a32bc7414e9d0c0ada     latest      1
# caac14a5bf2ba283db7708bb34855760     latest      0
# 13f10ba306a19ce7bec2f3cae507b698     latest      1
# 39c4b4dc0e9701b55a0a4f072008fb3f     latest      1
# bf5a572cca75f5fc67f4b14e58b11d70     latest      1

# %% [markdown]
# ## Preparing different dataframes for extracting features

# %%
# Merging items and view_logs
user_logs = pd.merge(user_log_df, item_df, how='left', on='item_id').fillna(0)
user_logs.head()
# Out:
#           server_time device_type  session_id  user_id  item_id  item_price  \
# 0 2018-10-15 08:58:00     android      112333     4557    32970     54685.0
# 1 2018-10-15 08:58:00     android      503590    74788     7640      1376.0
# 2 2018-10-15 08:58:00     android      573960    23628   128855      4544.0
# 3 2018-10-15 08:58:00     android      121691     2430    12774       904.0
# 4 2018-10-15 08:58:00     android      218564    19227    28296      2304.0
#
#    category_1  category_2  category_3  product_type
# 0        16.0        56.0       253.0        3184.0
# 1         7.0        71.0       228.0         545.0
# 2         4.0        38.0        62.0        5609.0
# 3        17.0        39.0       252.0        2740.0
# 4        12.0        57.0        54.0        7422.0

# %%
user_logs_by_time = user_logs.set_index(['user_id','server_time']).sort_index()
user_logs_by_time.head()
# Out:
#                             device_type  session_id  item_id  item_price  \
# user_id server_time
# 0       2018-10-18 14:27:00     android      268465    44459      3776.0
#         2018-10-18 14:27:00     android      268465    44459      3776.0
#         2018-10-18 14:43:00     android      268465    44459      3776.0
#         2018-10-18 14:46:00     android      268465    44459      3776.0
#         2018-10-18 14:46:00     android      268465    44459      3776.0
#
#                              category_1  category_2  category_3  product_type
# user_id server_time
# 0       2018-10-18 14:27:00        14.0        29.0       199.0        7363.0
#         2018-10-18 14:27:00        14.0        29.0       199.0        7363.0
#         2018-10-18 14:43:00        14.0        29.0       199.0        7363.0
#         2018-10-18 14:46:00        14.0        29.0       199.0        7363.0
#         2018-10-18 14:46:00        14.0        29.0       199.0        7363.0

# %%
user_logs_by_session = user_logs.set_index(['user_id','session_id','server_time']).sort_index()
user_logs_by_session.head()
# Out:
#                                        device_type  item_id  item_price  \
# user_id session_id server_time
# 0       86373      2018-12-04 07:19:00     android   116073      4181.0
#         143955     2018-11-11 10:09:00     android    89373      2496.0
#                    2018-11-11 10:10:00     android    10379      1238.0
#                    2018-11-11 10:10:00     android    10379      1238.0
#                    2018-11-11 10:11:00     android    89373      2496.0
#
#                                         category_1  category_2  category_3  \
# user_id session_id server_time
# 0       86373      2018-12-04 07:19:00        17.0        39.0       151.0
#         143955     2018-11-11 10:09:00        17.0         8.0       113.0
#                    2018-11-11 10:10:00        16.0        17.0       272.0
#                    2018-11-11 10:10:00        16.0        17.0       272.0
#                    2018-11-11 10:11:00        17.0         8.0       113.0
#
#                                         product_type
# user_id session_id server_time
# 0       86373      2018-12-04 07:19:00         124.0
#         143955     2018-11-11 10:09:00       10025.0
#                    2018-11-11 10:10:00          60.0
#                    2018-11-11 10:10:00          60.0
#                    2018-11-11 10:11:00       10025.0

# %%
train_test_data = training_data.append(testing_data, sort=False).fillna(0)
train_test_data.head()
# Out:
#                                      impression_time  user_id  app_code  \
# impression_id
# c4ca4238a0b923820dcc509a6f75849b 2018-11-15 00:00:00    87862       422
# 45c48cce2e2d7fbdea1afc51c7c6ad26 2018-11-15 00:01:00    63410       467
# 70efdf2ec9b086079795c442636b55fb 2018-11-15 00:02:00    71748       259
# 8e296a067a37563370ded05f5a3bf3ec 2018-11-15 00:02:00    69209       244
# 182be0c5cdcd5072bb1864cdee4d3d6e 2018-11-15 00:02:00    62873       473
#
#                                     os_version  is_4G  is_click
# impression_id
# c4ca4238a0b923820dcc509a6f75849b           old      0       0.0
# 45c48cce2e2d7fbdea1afc51c7c6ad26        latest      1       1.0
# 70efdf2ec9b086079795c442636b55fb  intermediate      1       0.0
# 8e296a067a37563370ded05f5a3bf3ec        latest      1       0.0
# 182be0c5cdcd5072bb1864cdee4d3d6e        latest      0       0.0

# %%
app_ad_history_action = training_data.set_index(['user_id','app_code','impression_time']).sort_index()
app_ad_history_action = app_ad_history_action[['is_click']]
app_ad_history_action.head()
# Out:
#                                       is_click
# user_id app_code impression_time
# 0       207      2018-11-26 23:30:00         0
# 2       190      2018-11-19 20:49:00         0
#                  2018-11-20 20:29:00         0
#                  2018-11-20 20:53:00         0
#                  2018-11-21 21:47:00         0

# %%
app_ad_history = train_test_data.set_index(['user_id','app_code','impression_time']).sort_index()
app_ad_history = app_ad_history[['is_click']]
app_ad_history.head()
# Out:
#                                       is_click
# user_id app_code impression_time
# 0       207      2018-11-26 23:30:00       0.0
# 1       386      2018-12-13 19:49:00       0.0
# 2       190      2018-11-19 20:49:00       0.0
#                  2018-11-20 20:29:00       0.0
#                  2018-11-20 20:53:00       0.0

# %%
ad_history_action = training_data.set_index(['user_id','impression_time']).sort_index()
ad_history_action = ad_history_action[['is_click']]
ad_history_action.head()
# Out:
#                              is_click
# user_id impression_time
# 0       2018-11-26 23:30:00         0
# 2       2018-11-19 20:49:00         0
#         2018-11-20 20:29:00         0
#         2018-11-20 20:53:00         0
#         2018-11-21 21:47:00         0

# %%
ad_history = train_test_data.set_index(['user_id','impression_time']).sort_index()
ad_history = ad_history[['is_click']]
ad_history.head()
# Out:
#                              is_click
# user_id impression_time
# 0       2018-11-26 23:30:00       0.0
# 1       2018-12-13 19:49:00       0.0
# 2       2018-11-19 20:49:00       0.0
#         2018-11-20 20:29:00       0.0
#         2018-11-20 20:53:00       0.0

# %% [markdown]
# ## Functions to extract useful features

# %%
idealTime = pd.Timestamp('2018-10-01 00:00:00')
def last_ad_seen(row):
    try:
        records = ad_history.loc[row.user_id, :][:row.impression_time][-3:-2]
        last_seen = records.index.values[0] if len(records) > 0 else idealTime
        return (pd.Timestamp(row.impression_time) - last_seen).total_seconds()
    except KeyError:
        return (pd.Timestamp(row.impression_time) - idealTime).total_seconds()
    
def app_last_ad_seen(row):
    try:
        records = app_ad_history.loc[(row.user_id, row.app_code), :][:row.impression_time][-3:-2]
        last_seen = records.index.values[0] if len(records) > 0 else idealTime
        return (pd.Timestamp(row.impression_time) - last_seen).total_seconds()
    except KeyError:
        return (pd.Timestamp(row.impression_time) - idealTime).total_seconds()

# %%
def calculate_click_ratio(records):
    total_ads = records.shape[0]
    total_clicks = records.is_click.sum()
    return (total_clicks / total_ads) if total_ads != 0 else 0.0

def app_wise_click_ratio(row, range_start, range_end):
    try:
        records = app_ad_history_action.loc[(row.user_id, row.app_code), :][range_start:range_end]
        return calculate_click_ratio(records)
    except KeyError:
        return 0.0

def overall_click_ratio(row, range_start, range_end):
    try:
        records = ad_history_action.loc[row.user_id, :][range_start:range_end]
        return calculate_click_ratio(records)
    except KeyError:
        return 0.0

# %%
# def last_active_session_length(user_id, session):
#     session_details = user_logs_by_session.loc[(user_id,session), :].index
#     return (session_details[-1] - session_details[0]).total_seconds()

def last_active_session(user_history, impression_time):
    ad_time = pd.Timestamp(impression_time)
    last_session_time = user_history.index.values[-1] if len(user_history) > 0 else idealTime
    return (ad_time - last_session_time).total_seconds()

# %%
range_start_delta = pd.Timedelta('31 days')
range_end_delta = pd.Timedelta('7 days')

def data_processing(row):
    user = row.user_id
    impression_time = pd.Timestamp(row.impression_time)
    range_start, range_end = impression_time - range_start_delta, impression_time - range_end_delta
    user_history = user_logs_by_time.loc[user,:][range_start:range_end]
    
    if user_history.item_id.count() == 0:
        row['total_items'] = 0
        row['unique_items'] = 0
        row['total_sessions'] = 0
        row['last_active_session'] = 0
#         row['session_length'] = 0
        row['mean_price'] = 0.0
        row['std_price'] = 0.0
        row['unique_product_type'] = 0
        row['freq_product_type'] = 0
        row['unique_cat1'] = 0
        row['freq_cat1'] = 0
        row['unique_cat2'] = 0
        row['freq_cat2'] = 0
        row['unique_cat3'] = 0
        row['freq_cat3'] = 0
        row['unique_device'] = 0
        row['freq_device'] = 0
        row['app_last_ad_seen'] = row['last_active_session']
        row['last_ad_seen'] = row['last_active_session']
        row['app_click_ratio'] = 0.0
        row['overall_click_ratio'] = 0.0
        
    else:
        row['total_items'] = user_history.item_id.count()
        row['unique_items'] = user_history.item_id.nunique()
        row['total_sessions'] = user_history.session_id.nunique()

        row['last_active_session'] = last_active_session(user_history, row.impression_time)
#         row['session_length'] = last_active_session_length(user, user_history.session_id.values[-1])

        row['mean_price'] = user_history.item_price.mean()
        row['std_price'] = user_history.item_price.std()

        row['unique_product_type'] = user_history.product_type.nunique()
        row['freq_product_type'] = user_history.product_type.value_counts().index[0]

        row['unique_cat1'] = user_history.category_1.nunique()
        row['freq_cat1'] = user_history.category_1.value_counts().index[0]

        row['unique_cat2'] = user_history.category_1.nunique()
        row['freq_cat2'] = user_history.category_1.value_counts().index[0]

        row['unique_cat3'] = user_history.category_1.nunique()
        row['freq_cat3'] = user_history.category_1.value_counts().index[0]

        row['unique_device'] = user_history.device_type.nunique()
        row['freq_device'] = user_history.device_type.value_counts().index[0]

        row['app_last_ad_seen'] = app_last_ad_seen(row)
        row['last_ad_seen'] = last_ad_seen(row)

        row['app_click_ratio'] = app_wise_click_ratio(row, range_start, range_end)
        row['overall_click_ratio'] = overall_click_ratio(row, range_start, range_end)
    
    return row

# %%
change_types = [
    ('last_active_session', 'int'),
    ('freq_cat3', 'int'),
    ('freq_cat2', 'int'),
    ('freq_cat1', 'int'),
    ('app_last_ad_seen', 'int'),
    ('last_ad_seen', 'int'),
    ('freq_product_type', 'int'),
]
def extract_features(dataset):
    dataset = dataset.apply(data_processing, axis=1)
    for col, dtype in change_types:
        dataset[col] = dataset[col].astype(dtype)
    dataset.os_version = dataset.os_version.replace({'latest':0,'intermediate': 1, 'old':2}).astype('int')
    dataset.freq_device = dataset.freq_device.replace({'android':0, 'web': 1, 'iphone':2}).astype('int')
    return dataset

# %%
sample_testing_data = testing_data.head()
sample_testing_data = extract_features(sample_testing_data)
sample_testing_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, a9e7126a585a69a32bc7414e9d0c0ada to bf5a572cca75f5fc67f4b14e58b11d70
# Data columns (total 25 columns):
# impression_time        5 non-null datetime64[ns]
# user_id                5 non-null int64
# app_code               5 non-null int64
# os_version             5 non-null int64
# is_4G                  5 non-null int64
# total_items            5 non-null int64
# unique_items           5 non-null int64
# total_sessions         5 non-null int64
# last_active_session    5 non-null int64
# mean_price             5 non-null float64
# std_price              5 non-null float64
# unique_product_type    5 non-null int64
# freq_product_type      5 non-null int64
# unique_cat1            5 non-null int64
# freq_cat1              5 non-null int64
# unique_cat2            5 non-null int64
# freq_cat2              5 non-null int64
# unique_cat3            5 non-null int64
# freq_cat3              5 non-null int64
# unique_device          5 non-null int64
# freq_device            5 non-null int64
# app_last_ad_seen       5 non-null int64
# last_ad_seen           5 non-null int64
# app_click_ratio        5 non-null float64
# overall_click_ratio    5 non-null float64
# dtypes: datetime64[ns](1), float64(4), int64(20)
# memory usage: 1.0+ KB

# %%
sample_testing_data
# Out:
#                                      impression_time  user_id  app_code  \
# impression_id
# a9e7126a585a69a32bc7414e9d0c0ada 2018-12-13 07:44:00    44754       127
# caac14a5bf2ba283db7708bb34855760 2018-12-13 07:45:00    29656        44
# 13f10ba306a19ce7bec2f3cae507b698 2018-12-13 07:46:00    25234       296
# 39c4b4dc0e9701b55a0a4f072008fb3f 2018-12-13 07:47:00    22988       207
# bf5a572cca75f5fc67f4b14e58b11d70 2018-12-13 07:48:00    35431       242
#
#                                   os_version  is_4G  total_items  \
# impression_id
# a9e7126a585a69a32bc7414e9d0c0ada           0      1            0
# caac14a5bf2ba283db7708bb34855760           0      0           22
# 13f10ba306a19ce7bec2f3cae507b698           0      1            3
# 39c4b4dc0e9701b55a0a4f072008fb3f           0      1           33
# bf5a572cca75f5fc67f4b14e58b11d70           0      1           15
#
#                                   unique_items  total_sessions  \
# impression_id
# a9e7126a585a69a32bc7414e9d0c0ada             0               0
# caac14a5bf2ba283db7708bb34855760            16              11
# 13f10ba306a19ce7bec2f3cae507b698             2               1
# 39c4b4dc0e9701b55a0a4f072008fb3f            14               9
# bf5a572cca75f5fc67f4b14e58b11d70            13               6
#
#                                   last_active_session    mean_price  ...  \
# impression_id                                                        ...
# a9e7126a585a69a32bc7414e9d0c0ada                    0      0.000000  ...
# caac14a5bf2ba283db7708bb34855760               923520  14290.681818  ...
# 13f10ba306a19ce7bec2f3cae507b698              2410980   1385.666667  ...
# 39c4b4dc0e9701b55a0a4f072008fb3f               695340  14548.606061  ...
# bf5a572cca75f5fc67f4b14e58b11d70              1001700   6946.866667  ...
#
#                                   unique_cat2  freq_cat2  unique_cat3  \
# impression_id
# a9e7126a585a69a32bc7414e9d0c0ada            0          0            0
# caac14a5bf2ba283db7708bb34855760           10         16           10
# 13f10ba306a19ce7bec2f3cae507b698            2         16            2
# 39c4b4dc0e9701b55a0a4f072008fb3f           10          9           10
# bf5a572cca75f5fc67f4b14e58b11d70            9         11            9
#
#                                   freq_cat3  unique_device  freq_device  \
# impression_id
# a9e7126a585a69a32bc7414e9d0c0ada          0              0            0
# caac14a5bf2ba283db7708bb34855760         16              1            0
# 13f10ba306a19ce7bec2f3cae507b698         16              1            0
# 39c4b4dc0e9701b55a0a4f072008fb3f          9              1            0
# bf5a572cca75f5fc67f4b14e58b11d70         11              1            0
#
#                                   app_last_ad_seen  last_ad_seen  \
# impression_id
# a9e7126a585a69a32bc7414e9d0c0ada                 0             0
# caac14a5bf2ba283db7708bb34855760           1128000       1128000
# 13f10ba306a19ce7bec2f3cae507b698           6335160       6335160
# 39c4b4dc0e9701b55a0a4f072008fb3f            815700        815700
# bf5a572cca75f5fc67f4b14e58b11d70            818460        818460
#
#                                   app_click_ratio  overall_click_ratio
# impression_id
# a9e7126a585a69a32bc7414e9d0c0ada         0.000000             0.000000
# caac14a5bf2ba283db7708bb34855760         0.000000             0.000000
# 13f10ba306a19ce7bec2f3cae507b698         0.000000             0.000000
# 39c4b4dc0e9701b55a0a4f072008fb3f         0.000000             0.000000
# bf5a572cca75f5fc67f4b14e58b11d70         0.210526             0.210526
#
# [5 rows x 25 columns]

# %% [markdown]
# ## Extracting Features

# %%
testing_data = pd.read_csv('data/test/test.csv', index_col='impression_id', parse_dates=['impression_time'])
testing_data = extract_features(testing_data)
testing_data.head()
# Out:
#                                      impression_time  user_id  app_code  \
# impression_id
# a9e7126a585a69a32bc7414e9d0c0ada 2018-12-13 07:44:00    44754       127
# caac14a5bf2ba283db7708bb34855760 2018-12-13 07:45:00    29656        44
# 13f10ba306a19ce7bec2f3cae507b698 2018-12-13 07:46:00    25234       296
# 39c4b4dc0e9701b55a0a4f072008fb3f 2018-12-13 07:47:00    22988       207
# bf5a572cca75f5fc67f4b14e58b11d70 2018-12-13 07:48:00    35431       242
#
#                                   os_version  is_4G  total_items  \
# impression_id
# a9e7126a585a69a32bc7414e9d0c0ada           0      1            0
# caac14a5bf2ba283db7708bb34855760           0      0           22
# 13f10ba306a19ce7bec2f3cae507b698           0      1            3
# 39c4b4dc0e9701b55a0a4f072008fb3f           0      1           33
# bf5a572cca75f5fc67f4b14e58b11d70           0      1           15
#
#                                   unique_items  total_sessions  \
# impression_id
# a9e7126a585a69a32bc7414e9d0c0ada             0               0
# caac14a5bf2ba283db7708bb34855760            16              11
# 13f10ba306a19ce7bec2f3cae507b698             2               1
# 39c4b4dc0e9701b55a0a4f072008fb3f            14               9
# bf5a572cca75f5fc67f4b14e58b11d70            13               6
#
#                                   last_active_session    mean_price  ...  \
# impression_id                                                        ...
# a9e7126a585a69a32bc7414e9d0c0ada                    0      0.000000  ...
# caac14a5bf2ba283db7708bb34855760               923520  14290.681818  ...
# 13f10ba306a19ce7bec2f3cae507b698              2410980   1385.666667  ...
# 39c4b4dc0e9701b55a0a4f072008fb3f               695340  14548.606061  ...
# bf5a572cca75f5fc67f4b14e58b11d70              1001700   6946.866667  ...
#
#                                   unique_cat2  freq_cat2  unique_cat3  \
# impression_id
# a9e7126a585a69a32bc7414e9d0c0ada            0          0            0
# caac14a5bf2ba283db7708bb34855760           10         16           10
# 13f10ba306a19ce7bec2f3cae507b698            2         16            2
# 39c4b4dc0e9701b55a0a4f072008fb3f           10          9           10
# bf5a572cca75f5fc67f4b14e58b11d70            9         11            9
#
#                                   freq_cat3  unique_device  freq_device  \
# impression_id
# a9e7126a585a69a32bc7414e9d0c0ada          0              0            0
# caac14a5bf2ba283db7708bb34855760         16              1            0
# 13f10ba306a19ce7bec2f3cae507b698         16              1            0
# 39c4b4dc0e9701b55a0a4f072008fb3f          9              1            0
# bf5a572cca75f5fc67f4b14e58b11d70         11              1            0
#
#                                   app_last_ad_seen  last_ad_seen  \
# impression_id
# a9e7126a585a69a32bc7414e9d0c0ada                 0             0
# caac14a5bf2ba283db7708bb34855760           1128000       1128000
# 13f10ba306a19ce7bec2f3cae507b698           6335160       6335160
# 39c4b4dc0e9701b55a0a4f072008fb3f            815700        815700
# bf5a572cca75f5fc67f4b14e58b11d70            818460        818460
#
#                                   app_click_ratio  overall_click_ratio
# impression_id
# a9e7126a585a69a32bc7414e9d0c0ada         0.000000             0.000000
# caac14a5bf2ba283db7708bb34855760         0.000000             0.000000
# 13f10ba306a19ce7bec2f3cae507b698         0.000000             0.000000
# 39c4b4dc0e9701b55a0a4f072008fb3f         0.000000             0.000000
# bf5a572cca75f5fc67f4b14e58b11d70         0.210526             0.210526
#
# [5 rows x 25 columns]

# %%
testing_data.to_csv('data/test/test_feature.csv')

# %%
training_data = pd.read_csv('data/train/train.csv', index_col='impression_id', parse_dates=['impression_time'])
training_data = extract_features(training_data)
training_data.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/TestEnv/lib/python3.7/site-packages/pandas/core/series.py in _set_with_engine(self, key, value)
#    1247         try:
# -> 1248             self.index._engine.set_value(values, key, value)
#    1249             return
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.set_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.set_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'last_active_session'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/TestEnv/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2889             try:
# -> 2890                 return self._engine.get_loc(key)
#    2891             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'last_active_session'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/TestEnv/lib/python3.7/site-packages/pandas/core/series.py in setitem(key, value)
#    1185             try:
# -> 1186                 self._set_with_engine(key, value)
#    1187                 return
#
# ~/anaconda3/envs/TestEnv/lib/python3.7/site-packages/pandas/core/series.py in _set_with_engine(self, key, value)
#    1250         except KeyError:
# -> 1251             values[self.index.get_loc(key)] = value
#    1252             return
#
# ~/anaconda3/envs/TestEnv/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2891             except KeyError:
# -> 2892                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2893         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'last_active_session'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-35-c0f7c917546b> in <module>
#       1 training_data = pd.read_csv('data/train/train.csv', index_col='impression_id', parse_dates=['impression_time'])
# ----> 2 training_data = extract_features(training_data)
#       3 training_data.head()
#
# <ipython-input-30-e47cf4fe663e> in extract_features(dataset)
#       9 ]
#      10 def extract_features(dataset):
# ---> 11     dataset = dataset.apply(data_processing, axis=1)
#      12     for col, dtype in change_types:
#      13         dataset[col] = dataset[col].astype(dtype)
#
# ~/anaconda3/envs/TestEnv/lib/python3.7/site-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6904             kwds=kwds,
#    6905         )
# -> 6906         return op.get_result()
#    6907
#    6908     def applymap(self, func):
#
# ~/anaconda3/envs/TestEnv/lib/python3.7/site-packages/pandas/core/apply.py in get_result(self)
#     184             return self.apply_raw()
#     185
# --> 186         return self.apply_standard()
#     187
#     188     def apply_empty_result(self):
#
# ~/anaconda3/envs/TestEnv/lib/python3.7/site-packages/pandas/core/apply.py in apply_standard(self)
#     290
#     291         # compute the result using the series generator
# --> 292         self.apply_series_generator()
#     293
#     294         # wrap results
#
# ~/anaconda3/envs/TestEnv/lib/python3.7/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     319             try:
#     320                 for i, v in enumerate(series_gen):
# --> 321                     results[i] = self.f(v)
#     322                     keys.append(v.name)
#     323             except Exception as e:
#
# <ipython-input-26-767eecfc3a98> in data_processing(row)
#      36         row['total_sessions'] = user_history.session_id.nunique()
#      37
# ---> 38         row['last_active_session'] = last_active_session(user_history, row.impression_time)
#      39 #         row['session_length'] = last_active_session_length(user, user_history.session_id.values[-1])
#      40
#
# ~/anaconda3/envs/TestEnv/lib/python3.7/site-packages/pandas/core/series.py in __setitem__(self, key, value)
#    1235         # do the setitem
#    1236         cacher_needs_updating = self._check_is_chained_assignment_possible()
# -> 1237         setitem(key, value)
#    1238         if cacher_needs_updating:
#    1239             self._maybe_update_cacher()
#
# ~/anaconda3/envs/TestEnv/lib/python3.7/site-packages/pandas/core/series.py in setitem(key, value)
#    1212                             pass
#    1213
# -> 1214                 self.loc[key] = value
#    1215                 return
#    1216
#
# ~/anaconda3/envs/TestEnv/lib/python3.7/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     200             key = com.apply_if_callable(key, self.obj)
#     201         indexer = self._get_setitem_indexer(key)
# --> 202         self._setitem_with_indexer(indexer, value)
#     203
#     204     def _validate_key(self, key, axis: int):
#
# ~/anaconda3/envs/TestEnv/lib/python3.7/site-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value)
#     390
#     391             if missing:
# --> 392                 return self._setitem_with_indexer_missing(indexer, value)
#     393
#     394         # set
#
# ~/anaconda3/envs/TestEnv/lib/python3.7/site-packages/pandas/core/indexing.py in _setitem_with_indexer_missing(self, indexer, value)
#     604
#     605             # this preserves dtype of the value
# --> 606             new_values = Series([value])._values
#     607             if len(self.obj._values):
#     608                 # GH#22717 handle casting compatibility that np.concatenate
#
# ~/anaconda3/envs/TestEnv/lib/python3.7/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     279                     "{0!r} type is unordered" "".format(data.__class__.__name__)
#     280                 )
# --> 281             elif isinstance(data, ABCSparseArray):
#     282                 # handle sparse passed here (and force conversion)
#     283                 data = data.to_dense()
#
# KeyboardInterrupt:

# %%
training_data.to_csv('data/train/train_feature.csv')
